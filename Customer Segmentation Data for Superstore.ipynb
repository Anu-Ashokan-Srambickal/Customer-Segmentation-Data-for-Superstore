# %% [markdown]
# # Customer Segmentation Data for Superstore

# %% [markdown]
# ### 🌍 IMPORTING LIBRARIES

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ________________________________________________________________________________________________________________________________

# %% [markdown]
# #### 🗂 DATASET LINK

# %% [markdown]
# https://www.kaggle.com/datasets/ahsan81/superstore-marketing-campaign-dataset

# %%
_________________________________________________________________________________________________________________________________

# %% [markdown]
# ### 📕 ABOUT DATASET

# %% [markdown]
# The superstore_data.csv dataset contains information on 2240 customers across 22 columns.
# * A quick overview of the data reveals the following:
#
# ### 🔺 Customer Demographics:
# * The dataset includes columns for Id, Year_Birth, Education, and Marital_Status.
#
# ### 🔺 Financial Information:
# * The Income column represents the customer's income and has 24 missing values.
#
# ### 🔺 Family Details:
# * The Kidhome and Teenhome columns show the number of children and teenagers in the household, respectively.
#
# ### 🔺 Customer History:
# * The Dt_Customer column records the date of customer enrollment.
#
# ### 🔺 Purchasing Behavior:
# * There are several columns related to purchasing, including Recency (days since the last purchase) and a series of columns prefixed with Mnt (e.g., MntWines) that represent spending on various products.
#
# ### 🔺 Interaction with the Store:
# * The data also contains columns like NumDealsPurchases, NumWebPurchases, NumCatalogPurchases, NumStorePurchases, and NumWebVisitsMonth, which show how customers interact with the store.
#
# ### 🔺  Engagement and Complaints:
# * The Response and Complain columns provide information on customer campaign responses and complaints.
#
# * The column data types are primarily integer (int64) for most of the numerical data, with the exception of Income, which is a float.
# * The Education, Marital_Status, and Dt_Customer columns are stored as objects.

# %% [markdown]
# _________________________________________________________________________________________________________________________________________

# %% [markdown]
# ### 🧾 Column Descriptions

# %% [markdown]
# ### 🔴 Customer Demographics:

# %% [markdown]
# |Column Name| Description|
# |------------|------------|
# |Id |A unique customer identifier.|
# |Year_Birth | The year of the customer's birth.|
# |Education |The customer's education level (e.g., Graduation, PhD, Master).|
# |Marital_Status| The customer's marital status.|
# |Income| The customer's annual household income. There are 24 missing values in this column.|
# |Kidhome| The number of small children in the customer's household.|
# |Teenhome |The number of teenagers in the customer's household.|

# %% [markdown]
# ________________________________________________________________________________________________________________________________

# %% [markdown]
# ### 🔴 Customer History:

# %% [markdown]
# |Column Name| Description|
# |------------|------------|
# |Dt_Customer |The date of the customer's enrollment with the company.|
# |Recency  |The number of days since the customer's last purchase.|

# %% [markdown]
# __________________________________________________________________________________________________________________________________

# %% [markdown]
# ### 🔴 Purchasing Behavior:

# %% [markdown]
# |Column Name| Description|
# |------------|------------|
# |MntWines, MntFruits, MntMeatProducts, MntFishProducts, MntSweetProducts, MntGoldProds:| Spending on various product categories.|
# |NumDealsPurchases |The number of purchases made with a discount.|
# |NumWebPurchases, NumCatalogPurchases, NumStorePurchases  |The number of purchases made through different channels.|
# |NumWebVisitsMonth |The number of visits to the company's website in the last month.|

# %% [markdown]
# ### 🔴 Engagement and Complaints:

# %% [markdown]
# |Column | Description|
# |------------|------------|
# |Response |Indicates whether the customer responded to the last marketing campaign (1=yes, 0=no).|
# |Complain  |Indicates whether the customer complained in the last 2 years (1=yes, 0=no).|

# %% [markdown]
# ### 🔴 Data Summary

# %% [markdown]
# * The dataset primarily consists of integer and object data types, with the Income column being a float.
# * A key finding is that income is positively correlated with higher education and negatively correlated with the number of web visits.
#
# * Spending habits are also strongly tied to income and vary significantly with education and marital status.
# * The presence of children and teenagers is negatively correlated with spending on certain products like wine and meat.

# %% [markdown]
# __________________________________________________________________________________________________________________________________

# %% [markdown]
# ### 📤 READING CSV

# %%
df = pd.read_csv(r'C:\Users\Surface Pro\Desktop\ENTRI APP\phython\self_projects\super_store\superstore_data.csv')
df
# Out:
#          Id  Year_Birth   Education Marital_Status   Income  Kidhome  \
# 0      1826        1970  Graduation       Divorced  84835.0        0
# 1         1        1961  Graduation         Single  57091.0        0
# 2     10476        1958  Graduation        Married  67267.0        0
# 3      1386        1967  Graduation       Together  32474.0        1
# 4      5371        1989  Graduation         Single  21474.0        1
# ...     ...         ...         ...            ...      ...      ...
# 2235  10142        1976         PhD       Divorced  66476.0        0
# 2236   5263        1977    2n Cycle        Married  31056.0        1
# 2237     22        1976  Graduation       Divorced  46310.0        1
# 2238    528        1978  Graduation        Married  65819.0        0
# 2239   4070        1969         PhD        Married  94871.0        0
#
#       Teenhome Dt_Customer  Recency  MntWines  ...  MntFishProducts  \
# 0            0   6/16/2014        0       189  ...              111
# ...

# %% [markdown]
# __________________________________________________________________________________________________________________________________

# %% [markdown]
# ### 🧬 UNDERSTANDING DATA

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2240 entries, 0 to 2239
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Id                   2240 non-null   int64
#  1   Year_Birth           2240 non-null   int64
#  2   Education            2240 non-null   object
#  3   Marital_Status       2240 non-null   object
#  4   Income               2216 non-null   float64
#  5   Kidhome              2240 non-null   int64
#  6   Teenhome             2240 non-null   int64
#  7   Dt_Customer          2240 non-null   object
#  8   Recency              2240 non-null   int64
#  9   MntWines             2240 non-null   int64
#  10  MntFruits            2240 non-null   int64
#  11  MntMeatProducts      2240 non-null   int64
#  12  MntFishProducts      2240 non-null   int64
#  13  MntSweetProducts     2240 non-null   int64
#  14  MntGoldProds         2240 non-null   int64
# ...

# %% [markdown]
# ### 🔴 DATA TYPES of ALL COLUMNS

# %%
df.dtypes
# Out:
# Id                       int64
# Year_Birth               int64
# Education               object
# Marital_Status          object
# Income                 float64
# Kidhome                  int64
# Teenhome                 int64
# Dt_Customer             object
# Recency                  int64
# MntWines                 int64
# MntFruits                int64
# MntMeatProducts          int64
# MntFishProducts          int64
# MntSweetProducts         int64
# MntGoldProds             int64
# NumDealsPurchases        int64
# NumWebPurchases          int64
# NumCatalogPurchases      int64
# NumStorePurchases        int64
# NumWebVisitsMonth        int64
# Response                 int64
# Complain                 int64
# dtype: object

# %% [markdown]
# ### 🔴 TOTAL NUMBER OF ROWS AND COLUMNS

# %%
df.shape
# Out:
# (2240, 22)

# %% [markdown]
# ### 🔴 EXTRACTING HEAD AND TAIL OF COLUMN

# %%
df.head()
# Out:
#       Id  Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 0   1826        1970  Graduation       Divorced  84835.0        0         0
# 1      1        1961  Graduation         Single  57091.0        0         0
# 2  10476        1958  Graduation        Married  67267.0        0         1
# 3   1386        1967  Graduation       Together  32474.0        1         1
# 4   5371        1989  Graduation         Single  21474.0        1         0
#
#   Dt_Customer  Recency  MntWines  ...  MntFishProducts  MntSweetProducts  \
# 0   6/16/2014        0       189  ...              111               189
# 1   6/15/2014        0       464  ...                7                 0
# 2   5/13/2014        0       134  ...               15                 2
# 3   11/5/2014        0        10  ...                0                 0
# 4    8/4/2014        0         6  ...               11                 0
#
# ...

# %%
df.tail()
# Out:
#          Id  Year_Birth   Education Marital_Status   Income  Kidhome  \
# 2235  10142        1976         PhD       Divorced  66476.0        0
# 2236   5263        1977    2n Cycle        Married  31056.0        1
# 2237     22        1976  Graduation       Divorced  46310.0        1
# 2238    528        1978  Graduation        Married  65819.0        0
# 2239   4070        1969         PhD        Married  94871.0        0
#
#       Teenhome Dt_Customer  Recency  MntWines  ...  MntFishProducts  \
# 2235         1    7/3/2013       99       372  ...               47
# 2236         0   1/22/2013       99         5  ...                3
# 2237         0   3/12/2012       99       185  ...               15
# 2238         0  11/29/2012       99       267  ...              149
# 2239         2    1/9/2012       99       169  ...              188
#
#       MntSweetProducts  MntGoldProds  NumDealsPurchases  NumWebPurchases  \
# ...

# %% [markdown]
# __________________________________________________________________________________________________________________________________

# %% [markdown]
# ### 🧹 DATA CLEANING

# %% [markdown]
# ### 🔴 FINDING MISSING VALUES

# %%
df.isnull()
# Out:
#          Id  Year_Birth  Education  Marital_Status  Income  Kidhome  Teenhome  \
# 0     False       False      False           False   False    False     False
# 1     False       False      False           False   False    False     False
# 2     False       False      False           False   False    False     False
# 3     False       False      False           False   False    False     False
# 4     False       False      False           False   False    False     False
# ...     ...         ...        ...             ...     ...      ...       ...
# 2235  False       False      False           False   False    False     False
# 2236  False       False      False           False   False    False     False
# 2237  False       False      False           False   False    False     False
# 2238  False       False      False           False   False    False     False
# 2239  False       False      False           False   False    False     False
#
# ...

# %% [markdown]
# ### 🔴 TOTAL NUMBER OF MISSING VALUES

# %%
df.isnull().sum()
# Out:
# Id                      0
# Year_Birth              0
# Education               0
# Marital_Status          0
# Income                 24
# Kidhome                 0
# Teenhome                0
# Dt_Customer             0
# Recency                 0
# MntWines                0
# MntFruits               0
# MntMeatProducts         0
# MntFishProducts         0
# MntSweetProducts        0
# MntGoldProds            0
# NumDealsPurchases       0
# NumWebPurchases         0
# NumCatalogPurchases     0
# NumStorePurchases       0
# NumWebVisitsMonth       0
# Response                0
# Complain                0
# dtype: int64

# %% [markdown]
# ### 🔴 FILLING AMOUNT COLUMN MISSING VALUE WITH 0

# %%
df.fillna({'Income':0}, inplace=True)

# %% [markdown]
# ### 🔴 CHECKING FOR DUPLICATES VALUES

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# __________________________________________________________________________________________________________________________________

# %% [markdown]
# ### 📝 STATISTICAL ANALYSIS

# %% [markdown]
# #### 🔴 STATISTICAL ANALYSIS OF NUMERIC DATA

# %%
df.describe()
# Out:
#                  Id   Year_Birth         Income      Kidhome     Teenhome  \
# count   2240.000000  2240.000000    2240.000000  2240.000000  2240.000000
# mean    5592.159821  1968.805804   51687.459375     0.444196     0.506250
# std     3246.662198    11.984069   25609.342730     0.538398     0.544538
# min        0.000000  1893.000000       0.000000     0.000000     0.000000
# 25%     2828.250000  1959.000000   34722.000000     0.000000     0.000000
# 50%     5458.500000  1970.000000   51075.000000     0.000000     0.000000
# 75%     8427.750000  1977.000000   68289.750000     1.000000     1.000000
# max    11191.000000  1996.000000  666666.000000     2.000000     2.000000
#
#            Recency     MntWines    MntFruits  MntMeatProducts  \
# count  2240.000000  2240.000000  2240.000000      2240.000000
# mean     49.109375   303.935714    26.302232       166.950000
# std      28.962453   336.597393    39.773434       225.715373
# ...

# %% [markdown]
# ### 🔴 STATISTICAL ANALYSIS OF CATEGORICAL DATA

# %%
df.describe(include=object)
# Out:
#          Education Marital_Status Dt_Customer
# count         2240           2240        2240
# unique           5              8         663
# top     Graduation        Married   8/31/2012
# freq          1127            864          12

# %% [markdown]
# __________________________________________________________________________________________________________________________________

# %% [markdown]
# ### 📜 LISTING UNIQUE VALUES IN CATEGORICAL DATA

# %% [markdown]
# #### 🔴 FINDING UNIQUE VALUES IN EDUCATION COLUMN

# %%
df['Education'].unique()
# Out:
# array(['Graduation', 'PhD', '2n Cycle', 'Master', 'Basic'], dtype=object)

# %% [markdown]
# #### 🔴 FINDING UNIQUE VALUE IN MARITAL STATUS COLUMN

# %%
df['Marital_Status'].unique()
# Out:
# array(['Divorced', 'Single', 'Married', 'Together', 'Widow', 'YOLO',
#        'Alone', 'Absurd'], dtype=object)

# %% [markdown]
# ____________________________________________________________________________________________________________________________________

# %% [markdown]
# _________________________________________________________________________________________________________________________________

# %% [markdown]
# ## 📊 EXPLORATORY DATA ANALYSIS AND VISUALIZAION

# %% [markdown]
# ### 🔴 ANALYSING RANGE OF INCOME

# %%
range = df['Income'].max()-df['Income'].min()
range
# Out:
# 666666.0

# %% [markdown]
# ### 🔴 ANALYSING VARIANCE OF INCOME

# %%
df['Income'].var()
# Out:
# 655838435.0416791

# %% [markdown]
# _____________________________________________________________________________________________________________________________________

# %% [markdown]
# ### 🟥 1. ANALYSING CUSTOMER CATEGORY

# %% [markdown]
#   🔴 A. FINDING THE CUSTOMER COUNT BASED ON EDUCATION

# %%
df['Education'].describe()
# Out:
# count           2240
# unique             5
# top       Graduation
# freq            1127
# Name: Education, dtype: object

# %%
plt.figure(figsize=(20,8))
sns.histplot(data=df, x='Education', color='blue')
plt.title('CUSTOMER COUNT BASED ON EDUCATION',size=20)
plt.show()

# %% [markdown]
# ### 🔴Here is the customer count based on their education level:
#
# |Education	|Customer_Count|
# |-----------|--------------|
# |Graduation	|1116|
# |PhD	|481|
# |Master	|365|
# |2n Cycle	|200|
# |Basic	|54|
#
#
# * The data shows that the majority of customers have a 'Graduation' education, followed by 'PhD' and 'Master's' degrees. The 'Basic' and '2n Cycle' education levels have the fewest customers.

# %% [markdown]
# __________________________________________________________________________________________________________________________________

# %% [markdown]
# ### 🟥 CUSTOMER COUNT BASED ON MARITAL STATUS

# %%
df['Marital_Status'].describe()
# Out:
# count        2240
# unique          8
# top       Married
# freq          864
# Name: Marital_Status, dtype: object

# %%
plt.figure(figsize=(20,8))
sns.countplot(data=df, x = 'Marital_Status', color='violet')
plt.title('CUSTOMER COUNT BASED ON MARITAL STATUS',size=20)
plt.show()

# %% [markdown]
# #### 🔴 Here is the customer count based on their marital status:
#
# * The data shows that the majority of the customers are 'Married', followed by those who are 'Together' and 'Single'. The marital statuses of 'Alone', 'Absurd', and 'YOLO' have the fewest customers.

# %% [markdown]
# |Marital_Status	|Customer_Count|
# |---------------|--------------|
# |Married	|857|
# |Together	|573|
# |Single	|471|
# |Divorced	|232|
# |Widow	|76|
# |Alone	|3|
# |Absurd	|2|
# |YOLO	|2|

# %% [markdown]
# __________________________________________________________________________________________________________________________________

# %% [markdown]
# ### 🟥 Summarizing based on Education

# %%
# Group the data by 'Education' and sum the numerical columns
summary_by_education = df.groupby('Education').sum(numeric_only=True)

summary_by_education
# Out:
#                  Id  Year_Birth      Income  Kidhome  Teenhome  Recency  \
# Education
# 2n Cycle    1134407      400321   9526638.0       97        83     9829
# Basic        291406      106783   1096538.0       34         5     2616
# Graduation  6370394     2219779  58835937.0      501       557    56390
# Master      1999350      727745  19314900.0      168       198    17607
# PhD         2730881      955497  27005896.0      195       291    23563
#
#             MntWines  MntFruits  MntMeatProducts  MntFishProducts  \
# Education
# 2n Cycle       40231       5878            28675             9639
# Basic            391        600              618              921
# Graduation    320371      34683           202284            48630
# Master        123238       8012            60450            11877
# PhD           196585       9744            81941            12990
#
#             MntSweetProducts  MntGoldProds  NumDealsPurchases  \
# Education
# ...

# %% [markdown]
# ### 🟥 INCOME GENERATED BY CUSTOMERS EDUCATION AND MARITAL STATUS

# %%
plt.figure(figsize=(20,8))
sns.barplot(data=df, x='Marital_Status', y='Income', hue='Education', errorbar=None)
plt.show()

# %% [markdown]
# ### Here are the key insights from the chart:
#
# ### 🔴 Income and Education:
# * Customers with a Ph.D. or Master's degree generally have a higher average income compared to other education levels.
# This is a consistent trend across most marital statuses.
#
# ### 🔴 Income and Marital Status:
# * Within each education category, the average income varies by marital status. For instance, among 'Graduation' customers, those who are 'Married' or 'Together' show a higher average income compared to 'Single' or 'Divorced' individuals.
# * The lowest average income is generally seen in the 'Basic' education group, regardless of marital status.
#
# ### 🔴 Highest Average Income:
# * The highest average income is observed in the 'PhD' education category for customers with a 'Together' marital status. Similarly, customers with a 'Master's' degree who are 'Married' or 'Together' also have very high average incomes.
#
# This analysis suggests a strong correlation between higher education levels and higher income, with marital status also playing a role in the average income within each education group.

# %% [markdown]
# __________________________________________________________________________________________________________________________________

# %% [markdown]
# ### 🟥 ANALYSING AVERAGE SPENDING BASED ON EDUCATION AND NUMBER OF DEALS

# %%
# Group by 'NumDealsPurchases' and 'Education' and calculate the mean of 'MntWines'
deals_edu_wines = df.groupby(['NumDealsPurchases', 'Education'])['MntWines'].mean().reset_index()
deals_edu_wines
# Out:
#     NumDealsPurchases   Education     MntWines
# 0                   0    2n Cycle   324.333333
# 1                   0  Graduation   604.608696
# 2                   0      Master   623.000000
# 3                   0         PhD   380.615385
# 4                   1    2n Cycle   237.109890
# 5                   1       Basic     2.241379
# 6                   1  Graduation   301.603272
# 7                   1      Master   367.938272
# 8                   1         PhD   443.613065
# 9                   2    2n Cycle   108.207547
# 10                  2       Basic     3.866667
# 11                  2  Graduation   221.020080
# 12                  2      Master   245.984848
# 13                  2         PhD   340.061404
# 14                  3    2n Cycle    99.700000
# 15                  3       Basic     3.000000
# 16                  3  Graduation   248.613793
# 17                  3      Master   235.240741
# 18                  3         PhD   403.287671
# ...

# %% [markdown]
# ### 🟥 Create a grouped bar chart to visualize the average wine spending

# %%
 
plt.figure(figsize=(15, 8))
sns.barplot(
    x='NumDealsPurchases',
    y='MntWines',
    hue='Education',
    data=deals_edu_wines,
    palette='viridis'
)
plt.title('Average Wine Spending by Number of Deal Purchases and Education Level', fontsize=16)
plt.xlabel('Number of Deals Purchased', fontsize=12)
plt.ylabel('Average Spending on Wines', fontsize=12)
plt.legend(title='Education')
plt.tight_layout()
plt.savefig('mnt_wines_by_deals_and_education.png')
plt.show()

# %% [markdown]
# ### 🟥 Here are the key observations:
#
# ### 🔴 Impact of Deals on Wine Spending:
# The chart shows a general trend where customers who make fewer deal purchases tend to have higher average spending on wines.
# For most education levels, the average spending on wines is highest for customers who make 0 to 3 deal purchases and declines as the number of deals increases.
#
# ### 🔴 Education Level Differences:
# There are variations across different education levels. For customers with the 'Master's' and 'PhD' education levels, the average spending on wines is consistently higher compared to other education levels for the same number of deal purchases.
# This suggests that highly educated customers may be more inclined to spend more on wine, regardless of deals.
#
# ### 🔴 Anomalies:
# There are some exceptions to the general trend, particularly for higher numbers of deal purchases.
# For example, customers who made a high number of deal purchases (e.g., 15) show a significant increase in average wine spending, but these data points are likely based on a very small number of customers and may not represent a broader trend.

# %% [markdown]
# __________________________________________________________________________________________________________________________________

# %% [markdown]
# ### 🟥 ANALYSING NUMBER DEAL PURCHASES MADE BY YEAR_BIRTH AND EDUCATION

# %%
# Group by 'Education' and 'Year_Birth' and calculate the mean of 'NumDealsPurchases'
deals_by_edu_year = df.groupby(['Education', 'Year_Birth'])['NumDealsPurchases'].mean().reset_index()

# Sort the results by 'NumDealsPurchases' in descending order to highlight the top groups
deals_by_edu_year = deals_by_edu_year.sort_values(by='NumDealsPurchases', ascending=False)

print("Top 10 Average Deal Purchases by Education and Year of Birth:")
print(deals_by_edu_year.head(10).to_markdown(index=False, numalign="left", stralign="left"))
# Out:
# Top 10 Average Deal Purchases by Education and Year of Birth:
# | Education   | Year_Birth   | NumDealsPurchases   |
# |:------------|:-------------|:--------------------|
# | 2n Cycle    | 1967         | 6                   |
# | Basic       | 1958         | 5                   |
# | Basic       | 1981         | 4.5                 |
# | PhD         | 1953         | 4.28571             |
# | PhD         | 1963         | 4.25                |
# | Master      | 1949         | 4.09091             |
# | 2n Cycle    | 1979         | 4                   |
# | Master      | 1973         | 4                   |
# | PhD         | 1982         | 3.85714             |
# | PhD         | 1954         | 3.81818             |

# %%
# Create a grouped bar chart to visualize the average deal purchases by education and year of birth
plt.figure(figsize=(20, 10))
sns.barplot(
    x='Year_Birth',
    y='NumDealsPurchases',
    hue='Education',
    data=deals_by_edu_year,
    palette='viridis'
)
plt.title('Average Number of Deal Purchases by Year of Birth and Education', fontsize=16)
plt.xlabel('Year of Birth', fontsize=12)
plt.ylabel('Average Number of Deals Purchased', fontsize=12)
plt.xticks(rotation=90)
plt.legend(title='Education')
plt.tight_layout()
plt.savefig('avg_deals_by_year_and_education.png')
plt.show()

# %% [markdown]
# ### 🔴 Summary of Deal Purchases by Year of Birth and Education
#
# * The analysis of NumDealsPurchases across different Year_Birth and Education levels reveals the following insights:
#
# * The average number of deal purchases varies significantly across both Year_Birth and Education groups.
#
# * The top average deal purchases are seen in the '2n Cycle' education group for the birth year 1967, followed by the 'Basic' education group for the birth year 1958.
#
# Across most birth years, the number of deal purchases tends to be between 1 and 3, but there are notable peaks in specific groups, as shown in the table and chart.

# %% [markdown]
# __________________________________________________________________________________________________________________________________

# %% [markdown]
# ### 🟥 CO RELATION OF NUMERICAL DATA

# %%
c=df.corr(numeric_only=True)
c
# Out:
#                            Id  Year_Birth    Income   Kidhome  Teenhome  \
# Id                   1.000000    0.000028  0.013095  0.002406 -0.002580
# Year_Birth           0.000028    1.000000 -0.161791  0.230176 -0.352111
# Income               0.013095   -0.161791  1.000000 -0.428669  0.019133
# Kidhome              0.002406    0.230176 -0.428669  1.000000 -0.036133
# Teenhome            -0.002580   -0.352111  0.019133 -0.036133  1.000000
# Recency             -0.046524   -0.019871 -0.003970  0.008827  0.016198
# MntWines            -0.022878   -0.157773  0.578650 -0.496297  0.004846
# MntFruits            0.004600   -0.017917  0.430842 -0.372581 -0.176764
# MntMeatProducts     -0.004437   -0.030872  0.584633 -0.437129 -0.261160
# MntFishProducts     -0.024475   -0.041625  0.438871 -0.387644 -0.204187
# MntSweetProducts    -0.007642   -0.018133  0.440744 -0.370673 -0.162475
# MntGoldProds        -0.013438   -0.061818  0.325916 -0.349595 -0.021725
# ...

# %%
plt.figure(figsize=(20,8))
sns.heatmap(c, annot=True)
plt.title('CO RELATION MATRIX')
plt.show()

# %% [markdown]
# ### 🔴 Inference:
#
# Based on the correlation matrix, here is a detailed analysis of the relationships between the numerical variables:

# %% [markdown]
# Top 10 Most Correlated Numerical Variables
# |Variable 1	|Variable 2	|Correlation|
# |-----------|------------|----------|
# |NumCatalogPurchases	|MntMeatProducts	|0.73|
# |NumStorePurchases	|MntWines	|0.64|
# |MntWines	|NumCatalogPurchases	|0.63|
# |MntFishProducts	|MntFruits	|0.59|
# |Income	|NumCatalogPurchases|	0.59|
# |MntMeatProducts	|Income	|0.58|
# |MntFishProducts	|MntSweetProducts	|0.58|
# |Income	|MntWines	|0.58|
# |MntFishProducts	|MntMeatProducts	|0.57|
# |MntSweetProducts	|MntFruits	|0.57|

# %% [markdown]
# __________________________________________________________________________________________________________________________________

# %% [markdown]
# ### Key Insights:
#
# ### 🔴 Purchasing Behavior & Spending:
# * There are very strong correlations between spending on certain products and the number of purchases through different channels. For example, a high correlation (0.73) exists between the amount spent on meat products (MntMeatProducts) and the number of catalog purchases (NumCatalogPurchases). This suggests that customers who buy more meat products tend to use catalogs more frequently. Similarly, spending on wines (MntWines) is strongly correlated with both catalog purchases and store purchases.
#
# ###  🔴 Income & Spending:
# * A customer's income appears to be a significant factor in their spending habits, with a notable positive correlation with spending on catalog purchases (0.59), meat products (0.58), and wines (0.58). This suggests that as income increases, so does the likelihood of purchasing these types of goods.
#
# ###  🔴 Cross-Product Relationships:
# * There are strong positive correlations among the different types of products. For instance, spending on fish products is highly correlated with spending on fruits and sweet products. This indicates that customers who purchase one of these items are also likely to purchase the others, which could be useful for cross-selling strategies.
#
# The analysis reveals that customer income and purchasing habits are closely intertwined, with catalog and store purchases strongly linked to spending on specific product categories like wines and meat.
# These insights can be valuable for developing targeted marketing campaigns and product recommendations.

# %% [markdown]
# __________________________________________________________________________________________________________________________________

# %% [markdown]
# Based on the analyses performed on the superstore_data.csv dataset, here is a summary of the key conclusions:
#
# ### 🔴 1. Demographics and Income
# ### 🔺 Education and Income:
# * There is a strong correlation between education level and income. Customers with Ph.D. and Master's degrees have a significantly higher average income than those with other education levels.
#
# #### 🔺 Marital Status:
# The dataset is primarily composed of customers who are 'Married' or 'Together,' followed by 'Single' and 'Divorced.'
#
# #### 🔺 Household Composition:
# * The presence of children and teenagers (Kidhome and Teenhome) shows an inverse relationship with customer spending, suggesting that households with more dependents may have different purchasing priorities or less disposable income for certain products like wines and meat.
#
# ### 🔴 2. Purchasing Behavior and Spending
# ### 🔺High-Value Customers:
# * Income is a major predictor of spending. Customers with higher incomes tend to spend more on products, particularly in categories like MntWines and MntMeatProducts.
#
# ### 🔺 Product Relationships:
# * There are strong positive correlations between spending on different product categories.
# * For example, customers who spend more on wines also tend to spend more on meat products.
# This suggests opportunities for cross-selling and bundling.
#
# ### Impact of Deals:
# * The number of deal purchases (NumDealsPurchases) is inversely related to average wine spending. Customers who make fewer deal purchases tend to spend more on wines, indicating that high-value customers may be less influenced by promotional deals and are more likely to make full-price purchases.
#
# ### 🔴 3. Purchasing Channels
# ### Catalog and Store Purchases:
# * There is a strong correlation between spending on wines and meat products and the number of catalog and store purchases.
# * This suggests that these customers might prefer traditional shopping methods over web purchases.
#
# ### 🔺 Web Visits:
# * The number of web visits per month has a negative correlation with income, indicating that customers with lower incomes may spend more time Browse online, possibly to find deals.
#
# Overall, the data suggests that the superstore's customer base is segmented by income, education, and family structure, all of which heavily influence spending and purchasing behavior. Understanding these relationships can help in tailoring marketing strategies and product offerings to specific customer segments.

# %% [markdown]
# __________________________________________________________________________________________________________________________________
